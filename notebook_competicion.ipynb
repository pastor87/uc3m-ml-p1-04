# %% [markdown]
# # **Primera práctica de Aprendizaje Automático**
# ### **Predicción de subscripción a un producto bancario - Competición**
# Paloma González (*100498978*) y Javier Pastor (*100499039*)
#
# El último paso consiste en aplicar el modelo final al conjunto de datos de la competición, que contiene instancias sin etiquetar. Antes de realizar las predicciones, aplicamos exactamente las mismas transformaciones que realizamos durante el EDA sobre la variable `pdays` (`wasContacted` y `contactedLabel`), garantizando así que las variables de entrada sean consistentes con las que el modelo aprendió durante el entrenamiento.
#
# Las predicciones resultantes se guardan en el fichero `predicciones.csv`, listas para ser entregadas en la competición.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from -r requirements.txt (line 1)) (3.10.8)
# Requirement already satisfied: seaborn in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from -r requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: pandas in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from -r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: scikit-learn in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from -r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: streamlit in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from -r requirements.txt (line 5)) (1.56.0)
# Requirement already satisfied: joblib in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from -r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2026.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (8.3.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (7.34.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (2.33.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from streamlit->-r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (2.19.0)
# Requirement already satisfied: colorama in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 5)) (5.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 5)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 5)) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 5)) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\paloma\documents\aprendizaje\uc3m-ml-p1-04\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# INTEGRANTES DEL GRUPO: Javier Pastor Peñalba, Paloma González Valdelomar

import pandas as pd
import joblib

# 1. Cargar los datos ciegos de competición
df_comp = pd.read_pickle('bank_competition.pkl')

#Aplicación de transformaciones
def pdays_transform(x):
    if x == -1: return 0
    else: return 1

df_comp["wasContacted"] = df_comp["pdays"].map(pdays_transform)

def bin_pdays(x):
    if x == -1: return 0
    if x < 100: return 1
    elif x < 200: return 2
    elif x < 400: return 3
    else: return 4

df_comp['contactedLabel'] = df_comp['pdays'].map(bin_pdays)
X_comp = df_comp.drop(columns=['pdays']) 

# 3. Cargar el modelo final
modelo = joblib.load('modelo_final.joblib')

# 4. Predecir
predicciones = modelo.predict(X_comp)

# 5. Guardar el archivo CSV
df_resultado = pd.DataFrame({'deposit': predicciones})
df_resultado.to_csv('predicciones.csv', index=False)

print("Predicciones guardadas en 'predicciones.csv'")
# Out:
# Predicciones guardadas en 'predicciones.csv'
